# %%
# Importating the data from data sets
import pandas as pd 
data = pd.read_csv("Titanic.train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.shape
# Out:
# (891, 12)

# %%
data.size
# Out:
# 10692

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(data['Survived'].unique())
print(data['Pclass'].unique())
print(data['Sex'].unique())
print(data['SibSp'].unique())
print(data['Parch'].unique())
print(data['Embarked'].unique())
# Out:
# [0 1]
# [3 1 2]
# ['male' 'female']
# [1 0 3 4 2 5 8]
# [0 1 2 5 3 4 6]
# ['S' 'C' 'Q' nan]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='Survived',data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Pclass',hue='Survived',data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(x='Sex',hue='Survived',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.violinplot(x='Sex',y = 'Age', hue ='Survived', data = data, split = True)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.countplot(x='SibSp', hue='Survived',data=data)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(x='Parch', hue = 'Survived', data=data)
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.countplot(x='Embarked', hue = 'Survived', data=data)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
data['Age'].hist(bins=70)
# Out:
# <Axes: >

# %%
sns.boxplot(x='Pclass',y='Age',data=data, palette='winter')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ##Variable Notes
# PassengerId Unique ID of the passenger
#
# Survived Survived (1) or died (0)
#
# Pclass Passenger's class (1st, 2nd, or 3rd)
#
# Name Passenger's name
#
# Sex Passenger's sex
#
# Age Passenger's age
#
# SibSp Number of siblings/spouses aboard the Titanic
#
# Parch Number of parents/children aboard the Titanic
#
# Ticket Ticket number
#
# Fare Fare paid for ticket
#
# Cabin Cabin number
#
# Embarked Where the passenger got on the ship (C - Cherbourg, S - Southampton, Q = Queenstown)

# %%
sns.catplot(x='Sex', data=data, kind='count')

#lets first check gender
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Now let Separate the gender by classes passing 'Sex' to the 'hue' parameter
sns.catplot(x='Pclass',data=data, hue='Sex', kind ='count')
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Wow, quite a few more makes in the 3rd class than an interesting find. However, It might be useful to know the split between males, females, and childrens,
# abd Children How can go about this .

# %%
# Create a new columns 'Person' in which every person under 16 is child.
data['Person'] = data.Sex
data.loc[data['Age']< 16, 'Person'] = 'Child'

# %%
# Checking the distribution
print(f"Person categories : {data.Person.unique()}\n=================================")
print(f"Distribution of person : {data.Person.value_counts()}\n=================================")
print(f"Mean age : {data.Age.mean()}\n=================================")
# Out:
# Person categories : ['male' 'female' 'Child']
# ...
# Distribution of person : male      537
# female    271
# Child      83
# Name: Person, dtype: int64
# ...
# Mean age : 29.69911764705882
# ...

# %% [markdown]
# # Excelent ! Now we have  seprated the passenger between femail, male, and chile. THIS WLL BE IMPORTANT LATER ON BECAUSE OF THE famouse "WOMEN AND Children first policy.

# %%
sns.catplot(x='Pclass', data=data, hue='Person', kind='count')
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Intersting , quite a bit of children in 3rd class and not so many in 1ST! How about we create a distribution of the ages to get a more percise picture of
# the who the passengers were.

# %%
# visualizing age distrubation 
data.Age.hist(bins=80)
# Out:
# <Axes: >

# %%
# Another way to visualize the data is to use FacetGrid to plot multiple kedplots on one plot

fig = sns.FacetGrid(data, hue="Sex", aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)

oldest = data['Age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig = sns.FacetGrid(data, hue="Person", aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)

oldest = data['Age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Let's do the same for class by changing the hue argument:

fig = sns.FacetGrid(data, hue="Pclass",aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)

oldest = data['Age'].max()

fig.set(xlim=(0, oldest))

fig.add_legend()
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# We'have good understanding where passengers were based on Sex, Age, and Class. So let's move on to our 2nd question . Where
# whaT Deck were the passenger on and how does that relate to there class?

# %% [markdown]
# 2. ##What does were the passengers on and how does that relate to their clasas?

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %% [markdown]
# Now we see that the Cabin columns has information on the deck, But it has serval nan values , so we'll have to drope them

# %%
# First we'll drop the NAN values and create a new object, deck  
deck = data['Cabin'].dropna()
deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
# Let's grab that letter for deck level with a simple for loop 
levels = []
for level in deck:
    levels.append(level[0])

cabin_df = pd.DataFrame(levels)
cabin_df.columns = ['Cabin']
cabin_df.sort_values(by='Cabin', inplace = True)
sns.catplot(x='Cabin', data=cabin_df, kind='count', palette='winter_d')
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# "T" deck value there which does't make sence, we can deop it out with the following code:
cabin_df = cabin_df[ cabin_df.Cabin != 'T']
sns.catplot(x='Cabin', data=cabin_df, kind='count', palette ='summer')
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Great now that we've analyzed the distribution by decks, let's go our third question

# %% [markdown]
# # 3 where did the passengers come from

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
# Now we can make a quick factorial of check out the results, note the 
# Order argument, used to deal with NAN Values 

sns.catplot(x='Embarked',data=data, hue='Pclass', kind = 'count', order=['C','Q','S'])
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
#  An intresting find here is tha in Queenstown, almost all the passengers that Boarded there were 3rd class.

# %% [markdown]
# 4 Who was alone and who was with family?

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
# Lets start by adding a new column to define alone 
# We'll add the parent / child column with the sibsp column

data['Alone'] = data.SibSp + data.Parch
data.Alone
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: Alone, Length: 891, dtype: int64

# %% [markdown]
# Now we Know that if the Alone Column is anything But 0, the passanger had family aboard and wasn't alone. Som let's
# Change the columns now so that value is greater then 0, we know the passenger was with his/her family, otherwise
# they were alone.

# %%
# Look For > 0 or == 0 to set alone status
#data.loc[data['Alone'] > 0, 'Alone'] ='with Family'
#data.loc[data['Alone'] == 0,'Alone'] = 'Alone'
#Lets check to make sure it worked

data.loc[data['Alone'] > 0, 'Alone'] = 'with Family'
data.loc[data['Alone'] == 0, 'Alone'] = 'Alone'

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  with Family
# 1      0          PC 17599  71.2833   C85        C  female  with Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %% [markdown]
# # Now let's get a simple visualization !
# sns.catplot(x ='Alone',data=data, kind='count', palette='Blues',order=['Alone','with Family'])

# %% [markdown]
# # Great work! Now that we've throught analyzed the data let's go ahead and take a look at the most interesting (and Open-ending )
# Question 'What factor helping someone survive the sinking?

# %% [markdown]
# #5. What factore helping someone survive the sinking?

# %%
# let's start by creating a new column for legibility purposes through mapping 
data['Survivor'] = data.Survived.map({0:'No', 1:'Yes'})

#Let's just get a quick overall view of Survived vs died.
sns.catplot(x='Survivor', data=data, kind='count')
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# So quite a few more people died than those who survived. Let's see if the class of the passengers had an effect on their survival rate, since the movie Titanic popularized the notion that the 3rd class passengers did not do as well as their 1st and 2nd class counterparts.

# %%
# Lets use a factor plot again, But now considering class 
sns.catplot(x='Pclass', y='Survived', data=data, kind='point')
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Look like survival rates for the 3rd class are substantially lower! But maybe this effect is being caused by the large amount of men in the 3rd class in combination with the women and children first policy. Let's use 'hue' to get a clearer picture on this.

# %%
# Lets use a factor plot again, But Now considering class and gender
sns.catplot(x ='Pclass', y='Survived', data=data, hue='Person', kind='point')
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
#  From this data it look like beign a male or beign in 3rd class were both not favourable for survived
# Enven regardless of class the result of beign a male in any class dramatically decreases
# your chance of survival
# But waht about age? Did being younger or older have an effect on survival rate?

# %%
# Lets use a line plot an age versus survival 
#sns.Implot(x='Age', y='Survived', data=data)
# Let's use a linear plot on age versus survival
sns.lmplot(x='Age', y='Survived', data=data)
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Looks like there is a general trend that the older the passenger was, the less likely they survived. Let's go ahead and use hue to take a look at the effect of class and age.

# %%
# Lets use a linear plot on age versus using hue for class seperation
sns.lmplot(x='Age', y = 'Survived', hue='Pclass', data=data)
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Let's use a linear plot on age varsus survival using hue for class Seperation 
generations = [10, 20, 40, 60, 80]
sns.lmplot(x='Age', y ='Survived', hue = 'Pclass', data=data , palette='winter',x_bins=generations)
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Intreasting find on the older 1st class passengers! what about if we relate gender and age with the survival set?

# %%
sns.lmplot(x='Age',y='Survived', hue = 'Sex', data=data, palette='winter', x_bins=generations)
# Out:
# C:\Users\amitg\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Awesome! we've gotten some really great insights on how gender,age, and class all related to a passengers chance of survival. Now you take control: Answer the following questions using pandas and seaborn:

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.to_csv('data1.csv',index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 pd.read_csv('data1')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
